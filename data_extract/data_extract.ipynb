# %%
from pathlib import Path
import tempfile
import tarfile
import zstandard  

import os
from glob import iglob

import json
from collections import defaultdict
import numpy as np
import pandas as pd

# %%
#extract zst files function
# from https://gist.github.com/scivision/ad241e9cf0474e267240e196d7545eca
def extract_zst(archive: Path, out_path: Path):
    """extract .zst file
    works on Windows, Linux, MacOS, etc.
    
    Parameters
    ----------
    archive: pathlib.Path or str
      .zst file to extract
    out_path: pathlib.Path or str
      directory to extract files and directories to
    """

    archive = Path(archive).expanduser()
    out_path = Path(out_path).expanduser().resolve()
    # need .resolve() in case intermediate relative dir doesn't exist

    dctx = zstandard.ZstdDecompressor()

    with tempfile.TemporaryFile(suffix=".tar") as ofh:
        with archive.open("rb") as ifh:
            dctx.copy_stream(ifh, ofh)
        ofh.seek(0)
        with tarfile.open(fileobj=ofh) as z:
            z.extractall(out_path)

# %%
#local variables to file path, set as needed
path_to_zst = "/Users/ryanlnewbury/Downloads/acousticbrainz-highlevel-json-20220623-0.tar.zst"
path_to_zst_extract = "/Users/ryanlnewbury/Downloads/highlevel"

# %%
extract_zst(path_to_zst,
            path_to_zst_extract)
# Out:
# KeyboardInterrupt

# %%
#creates directory route for every file in database
local_path = "/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel"
rootdir_glob = local_path + "/**/*"
# This will return absolute paths
file_list = [f for f in iglob(rootdir_glob, recursive=True) if os.path.isfile(f)]

# %%
#list of directories
file_list[:20]
# Out:
# ['/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619aa0ff-588d-4764-a7b8-25d5ec3f287f-1.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61959535-0a81-4aac-ba6a-6c1837a1abc0-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619c913b-975c-404c-bcbb-dfde093f6cd8-1.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619e8920-070f-403f-a382-207693e8ad8b-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61957c67-1a86-4d32-99b8-ef234ff88e68-4.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61957c67-1a86-4d32-99b8-ef234ff88e68-5.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619ee6cc-e9b6-4bd5-a6de-afd5cdebd96e-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619c913b-975c-404c-bcbb-dfde093f6cd8-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619f56b1-043a-412d-a034-7fb46fa29623-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619aa0ff-588d-4764-a7b8-25d5ec3f287f-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61998906-d002-47f2-9c5b-e8b2b2b66bd4-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61951827-0f5a-4792-9eb6-9b387c0b2172-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6190df86-a7c8-45fb-ba1c-462f4e73afe1-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61954635-6f63-46f5-a5c2-31ab1d3a6148-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/6192016b-266c-4c39-8187-eea841975c02-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619895d4-3f4a-4800-bf67-b33ea54225fe-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61923ead-c4de-4f06-8d2f-b61048ff9dbf-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619be962-59e1-4377-821a-9638a5ec8c91-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/619e63ca-4c82-470a-b84e-e82ff3fadcd2-0.json',
#  '/Users/ryanlnewbury/Downloads/highlevel/acousticbrainz-highlevel-json-20220623/highlevel/61/9/61957c67-1a86-4d32-99b8-ef234ff88e68-2.json']

# %%
#example json
f = open(file_list[0])
data = json.load(f)
data
# Out:
# {'highlevel': {'danceability': {'all': {'danceable': 0.040728867054,
#     'not_danceable': 0.959271132946},
#    'probability': 0.959271132946,
#    'value': 'not_danceable',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'gender': {'all': {'female': 0.256680905819, 'male': 0.743319094181},
#    'probability': 0.743319094181,
#    'value': 'male',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_dortmund': {'all': {'alternative': 4.77929384957e-09,
#     'blues': 5.2068469536e-09,
#     'electronic': 0.99997407198,
#     'folkcountry': 1.44785815337e-06,
#     'funksoulrnb': 1.46414706137e-07,
#     'jazz': 2.19145786104e-05,
#     'pop': 5.81779033837e-08,
#     'raphiphop': 1.89042044241e-08,
#     'rock': 2.36148002841e-06},
#    'probability': 0.99997407198,
#    'value': 'electronic',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_electronic': {'all': {'ambient': 0.754632353783,
#     'dnb': 0.00486668711528,
#     'house': 0.115324743092,
#     'techno': 0.0353940762579,
#     'trance': 0.0897821187973},
#    'probability': 0.754632353783,
#    'value': 'ambient',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_rosamerica': {'all': {'cla': 0.11807589978,
#     'dan': 0.0151058593765,
#     'hip': 0.0591320805252,
#     'jaz': 0.418451905251,
#     'pop': 0.0282642245293,
#     'rhy': 0.311201065779,
#     'roc': 0.0151791470125,
#     'spe': 0.0345898270607},
#    'probability': 0.418451905251,
#    'value': 'jaz',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'genre_tzanetakis': {'all': {'blu': 0.0536252483726,
#     'cla': 0.0402149371803,
#     'cou': 0.0643420740962,
#     'dis': 0.0643410608172,
#     'hip': 0.0804266482592,
#     'jaz': 0.321710467339,
#     'met': 0.0536201782525,
#     'pop': 0.0804298371077,
#     'reg': 0.0804299339652,
#     'roc': 0.160859629512},
#    'probability': 0.321710467339,
#    'value': 'jaz',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'ismir04_rhythm': {'all': {'ChaChaCha': 0.0236017722636,
#     'Jive': 0.00258830678649,
#     'Quickstep': 0.000776752480306,
#     'Rumba-American': 0.00477747246623,
#     'Rumba-International': 0.00141336477827,
#     'Rumba-Misc': 0.00647592311725,
#     'Samba': 0.00264113186859,
#     'Tango': 0.742780447006,
#     'VienneseWaltz': 0.214060992002,
#     'Waltz': 0.000883827335201},
#    'probability': 0.742780447006,
#    'value': 'Tango',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_acoustic': {'all': {'acoustic': 0.5, 'not_acoustic': 0.5},
#    'probability': 0.5,
#    'value': 'acoustic',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_aggressive': {'all': {'aggressive': 4.15862558611e-07,
#     'not_aggressive': 0.999999582767},
#    'probability': 0.999999582767,
#    'value': 'not_aggressive',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_electronic': {'all': {'electronic': 0.645610690117,
#     'not_electronic': 0.354389280081},
#    'probability': 0.645610690117,
#    'value': 'electronic',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_happy': {'all': {'happy': 1.22507185552e-06,
#     'not_happy': 0.999998748302},
#    'probability': 0.999998748302,
#    'value': 'not_happy',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_party': {'all': {'not_party': 0.995282709599,
#     'party': 0.0047172983177},
#    'probability': 0.995282709599,
#    'value': 'not_party',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_relaxed': {'all': {'not_relaxed': 0.145509257913,
#     'relaxed': 0.854490756989},
#    'probability': 0.854490756989,
#    'value': 'relaxed',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'mood_sad': {'all': {'not_sad': 0.50952154398, 'sad': 0.49047845602},
#    'probability': 0.50952154398,
#    'value': 'not_sad',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'moods_mirex': {'all': {'Cluster1': 0.0846713930368,
#     'Cluster2': 0.0909200161695,
#     'Cluster3': 0.356173604727,
#     'Cluster4': 0.0893081948161,
#     'Cluster5': 0.3789267838},
#    'probability': 0.3789267838,
#    'value': 'Cluster5',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'timbre': {'all': {'bright': 0.0198387987912, 'dark': 0.980161190033},
#    'probability': 0.980161190033,
#    'value': 'dark',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'tonal_atonal': {'all': {'atonal': 0.584256827831, 'tonal': 0.415743201971},
#    'probability': 0.584256827831,
#    'value': 'atonal',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}},
#   'voice_instrumental': {'all': {'instrumental': 0.997198760509,
#     'voice': 0.00280125695281},
#    'probability': 0.997198760509,
#    'value': 'instrumental',
#    'version': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'}}},
#  'metadata': {'audio_properties': {'analysis_sample_rate': 44100,
#    'bit_rate': 0,
#    'codec': 'flac',
#    'downmix': 'mix',
#    'equal_loudness': 0,
#    'length': 464.453338623,
#    'lossless': 1,
#    'md5_encoded': 'cd6a4bd1ae98bdee8a6af89722cdfa7a',
#    'replay_gain': -3.96155166626},
#   'tags': {'acoustid_id': ['e190de0d-ebdb-4fe7-a84b-9d8eef66a626'],
#    'album': ['The Fugitive'],
#    'album artist': ['James Newton Howard'],
#    'albumartist': ['James Newton Howard'],
#    'albumartistsort': ['Howard, James Newton'],
#    'artist': ['James Newton Howard'],
#    'artistsort': ['Howard, James Newton'],
#    'asin': ['B0030JM9KC'],
#    'barcode': ['826924111222'],
#    'catalognumber': ['LLLCD 1112'],
#    'composer': ['James Newton Howard'],
#    'date': ['1993'],
#    'disc': ['2'],
#    'discnumber': ['2'],
#    'disctotal': ['2'],
#    'ensemble': ['James Newton Howard'],
#    'file_name': 'CD2 18 Helicopter Chase _ The Sewer (Synth Demos).flac',
#    'genre': ['Soundtrack'],
#    'label': ['La-La Land Records'],
#    'media': ['CD'],
#    'musicbrainz_albumartistid': ['f6580b26-77f7-4a7b-8513-6db0476e8f21'],
#    'musicbrainz_albumid': ['8c86f116-4925-4a97-9f86-7786a3cdb00a'],
#    'musicbrainz_artistid': ['f6580b26-77f7-4a7b-8513-6db0476e8f21'],
#    'musicbrainz_recordingid': ['619aa0ff-588d-4764-a7b8-25d5ec3f287f'],
#    'musicbrainz_releasegroupid': ['445df99a-b448-342f-ae9e-7b413c5f692b'],
#    'originaldate': ['1993'],
#    'releasecountry': ['US'],
#    'releasestatus': ['official'],
#    'releasetype': ['album', 'soundtrack'],
#    'script': ['Latn'],
#    'title': ['Helicopter Chase / The Sewer (Synth Demos)'],
#    'totaldiscs': ['2'],
#    'totaltracks': ['19'],
#    'tracknumber': ['18'],
#    'tracktotal': ['19']},
#   'version': {'highlevel': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '8e24b98b71ad84f3024c7541412f02124a26d327',
#     'essentia_git_sha': 'v2.1_beta1-228-g260734a',
#     'extractor': 'music 1.0',
#     'gaia': '2.4-dev',
#     'gaia_git_sha': '857329b',
#     'models_essentia_git_sha': 'v2.1_beta1'},
#    'lowlevel': {'essentia': '2.1-beta1',
#     'essentia_build_sha': '7f154e5731828a63663f0144680ef47bd640f88b',
#     'essentia_git_sha': 'v2.1_beta1-6-g5578087',
#     'extractor': 'music 1.0'}}}}

# %%
data['metadata']['version'].keys()
# Out:
# dict_keys(['highlevel', 'lowlevel'])

# %%
#extraxts data for every file in directories
#cuation this will take a while
dic = defaultdict(list)
for d in file_list:
        f = open(d)
        data = json.load(f)
        #doesn't collect data if no metadata
        if data.get('metadata') == None:
            continue
        #gets mbid from file title
        temp = d.split('\\')[-1].split('-')
        temp.pop(-1);
        id1 = '-'.join(temp)
        #deduplicates mbids by only allowing one id into dictionary
        if id1 in dic['id']:
            continue
        else:
            dic['id'].append(id1)
        #appends new information to dicts
        dic['danceability'].append(data.get('highlevel').get('danceability').get('all').get('danceable'))
        dic['gender_male'].append(data.get('highlevel').get('gender').get('all').get('male'))
        dic['alternative'].append(data.get('highlevel').get('genre_dortmund').get('all').get('alternative'))
        dic['blues'].append(data.get('highlevel').get('genre_dortmund').get('all').get('blues'))
        dic['electronic'].append(data.get('highlevel').get('genre_dortmund').get('all').get('electronic'))
        dic['folkcountry'].append(data.get('highlevel').get('genre_dortmund').get('all').get('folkcountry'))
        dic['funksoulrnb'].append(data.get('highlevel').get('genre_dortmund').get('all').get('funksoulrnb'))
        dic['jazz'].append(data.get('highlevel').get('genre_dortmund').get('all').get('jazz'))
        dic['pop'].append(data.get('highlevel').get('genre_dortmund').get('all').get('pop'))
        dic['raphiphop'].append(data.get('highlevel').get('genre_dortmund').get('all').get('raphiphop'))
        dic['rock'].append(data.get('highlevel').get('genre_dortmund').get('all').get('rock'))
        dic['genre'].append(data.get('highlevel').get('genre_dortmund').get('value'))
        dic['acoustic'].append(data.get('highlevel').get('mood_acoustic').get('all').get('acoustic'))
        dic['aggressive'].append(data.get('highlevel').get('mood_aggressive').get('all').get('aggressive'))
        dic['mood_electronic'].append(data.get('highlevel').get('mood_electronic').get('all').get('electronic'))
        dic['happy'].append(data.get('highlevel').get('mood_happy').get('all').get('happy'))
        dic['party'].append(data.get('highlevel').get('mood_party').get('all').get('party'))
        dic['relaxed'].append(data.get('highlevel').get('mood_relaxed').get('all').get('relaxed'))
        dic['sad'].append(data.get('highlevel').get('mood_sad').get('all').get('sad'))
        dic['mood_mirex_1'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster1'))
        dic['mood_mirex_2'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster2'))
        dic['mood_mirex_3'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster3'))
        dic['mood_mirex_4'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster4'))
        dic['mood_mirex_5'].append(data.get('highlevel').get('moods_mirex').get('all').get('Cluster5'))
        dic['timbre_bright'].append(data.get('highlevel').get('timbre').get('all').get('bright'))
        dic['tonal'].append(data.get('highlevel').get('tonal_atonal').get('all').get('tonal'))
        dic['instrumental'].append(data.get('highlevel').get('voice_instrumental').get('all').get('instrumental'))
        dic['bit_rate'].append(data.get('metadata').get('audio_properties').get('bit_rate'))
        dic['codec'].append(data.get('metadata').get('audio_properties').get('codec'))
        dic['length'].append(data.get('metadata').get('audio_properties').get('length'))
        dic['lossless'].append(data.get('metadata').get('audio_properties').get('lossless'))
        dic['replay_gain'].append(data.get('metadata').get('audio_properties').get('replay_gain'))
        dic['true_genre'].append(data.get('metadata').get('tags').get('genre'))

        #same with metadata, but metadata in lists so needs an except if the list is empty
        try:
            dic['artist'].append(data.get('metadata').get('tags').get('artist')[0])
        except:
            dic['artist'].append(data.get('metadata').get('tags').get('artist'))       
        try:
            dic['album'].append(data.get('metadata').get('tags').get('album')[0])
        except:
            dic['album'].append(data.get('metadata').get('tags').get('album'))
        try:
            dic['bpm'].append(data.get('metadata').get('tags').get('bpm')[0])
        except:
            dic['bpm'].append(data.get('metadata').get('tags').get('bpm'))
        try:
            dic['year'].append(int(data.get('metadata').get('tags').get('date')[0].split('-')[0]))
        except:
            dic['year'].append(data.get('metadata').get('tags').get('date'))
        try:
            dic['date'].append(data.get('metadata').get('tags').get('date')[0])     
        except:
            dic['date'].append(data.get('metadata').get('tags').get('date'))
        try:
            dic['label'].append(data.get('metadata').get('tags').get('label')[0])
        except:
            dic['label'].append(data.get('metadata').get('tags').get('label'))
        try:
            dic['song'].append(data.get('metadata').get('tags').get('title')[0])
        except:
            dic['song'].append(data.get('metadata').get('tags').get('title'))
        try:
            dic['artistsort'].append(data.get('metadata').get('tags').get('artistsort')[0])
        except:
            dic['artistsort'].append(data.get('metadata').get('tags').get('artistsort'))

# %%
#creates dataframe from dict created
data = pd.DataFrame(dic)

# %%
len(data)
# Out:
# 754286

# %%
#number of rows with a value in year
data['year'].count()
# Out:
# 730178

# %%
#remove null years
data = data[data['year'].isnull() == False]

# %%
len(data)
# Out:
# 730178

# %%
data.head(10)
# Out:
#                                       id  danceability  gender_male  \
# 0   00000baf-9215-483a-8900-93756eaf1cfc  9.999094e-01     0.500000
# 2   00002fc9-7283-44dd-bf6f-94c9492d0998  9.128905e-01     0.177181
# 3   00005a44-2152-4971-80c1-c217563845eb  2.611271e-01     0.013684
# 4   000078f4-308b-44a1-8601-6bc37d9e1623  4.287960e-07     0.490970
# 5   00007960-9d81-4192-b548-ad33d6b0ca54  4.546444e-01     0.922832
# 6   00008af6-1070-45d5-936d-fd22a5394dd7  9.482443e-01     0.149076
# 7   0000975b-110a-428a-b329-5207d4eb675f  1.068272e-01     0.985882
# 8   0000bbe1-12f7-48de-8737-a5ac362e76c8  7.733440e-03     0.875382
# 9   0000d8a7-8a9b-4b9d-a95c-038c6cb66547  9.612730e-01     0.939157
# 10  0001093f-3ca1-42c8-bcc7-8fbbcd2f7c72  2.814359e-01     0.983833
#
#      alternative         blues  electronic   folkcountry   funksoulrnb  \
# 0   1.232231e-01  2.935208e-02    0.678169  1.836665e-02  4.645366e-03
# 2   6.570297e-02  6.069383e-02    0.538495  1.011928e-01  2.309020e-02
# 3   8.683714e-03  4.818535e-04    0.988906  9.305365e-04  3.203383e-05
# 4   1.094945e-01  2.266773e-03    0.862300  1.392666e-02  2.019748e-04
# 5   4.180764e-01  4.206907e-02    0.384046  5.705131e-02  4.202647e-03
# 6   1.588343e-01  8.892059e-02    0.345241  8.827031e-02  2.571717e-02
# 7   7.420029e-02  1.136003e-01    0.371166  2.652968e-01  1.488504e-02
# 8   4.348425e-14  5.558130e-14    1.000000  2.061889e-08  1.918473e-08
# 9   2.280277e-01  2.217325e-02    0.621480  6.854345e-02  2.393640e-03
# 10  1.495392e-01  3.137565e-02    0.669721  4.712693e-02  3.812399e-03
#
#             jazz           pop  ...  replay_gain     true_genre  \
# 0   2.795881e-02  7.834436e-03  ...    -6.764685           None
# 2   3.234591e-02  3.749089e-02  ...   -11.074022      [Hip-Hop]
# 3   2.341192e-04  7.360673e-05  ...    -5.080051         [Rock]
# 4   4.161819e-04  2.697128e-03  ...   -11.506065   [Space Rock]
# 5   6.691809e-03  1.481296e-02  ...    -5.130407   [Indie Rock]
# 6   6.783130e-02  4.839006e-02  ...    -5.078226       [Oldies]
# 7   2.762670e-02  1.748554e-02  ...    -8.468992           None
# 8   1.619071e-07  1.467535e-08  ...    -4.478720    [Classical]
# 9   4.151657e-03  9.586353e-03  ...    -5.745031  [Alternative]
# 10  6.459226e-03  7.076079e-03  ...    -8.899014  [Alternative]
#
#                     artist                                  album     bpm  \
# 0               In Extremo                       Weckt die Toten!    None
# 2              Danny Brown                                    Old    None
# 3                  Warlock                    Burning the Witches  128.1吵
# 4            Spiritualized           The Complete Works, Volume 1   119.6
# 5            Dandy Warhols         ...The Dandy Warhols Come Down  116.03
# 6             Petula Clark         The Atomic Café: French Cuts 2   86.94
# 7             Doug Kershaw             The Crazy Cajun Recordings    None
# 8     Ludwig van Beethoven               Piano Sonatas (Complete)    None
# 9            Kaiser Chiefs  Education, Education, Education & War   91.35
# 10  Motion City Soundtrack                    Even If It Kills Me  156.01
#
#     year        date                label  \
# 0   1998  1998-05-01                  EFA
# 2   2013  2013-10-08  Fool's Gold Records
# 3   1984        1984                 None
# 4   2003  2003-04-15               Arista
# 5   1997        1997      Capitol Records
# 6   2003        2003                 None
# 7   1998        1998        Edsel Records
# 8   2005        2005   Brilliant Classics
# 9   2014        2014      Fiction Records
# 10  2007        2007       Epitaph Europe
#
#                                                  song              artistsort
# 0                                          Como Poden              In Extremo
# 2                                              Lonely            Brown, Danny
# 3                                         Without You                    None
# 4   Lay Back in the Sun (‘Electric Mainline’ EP ve...           Spiritualized
# 5            Not If You Were the Last Junkie on Earth                    None
# 6                       A Well Respected Man (Franz.)                    None
# 7                                   You Done Me Wrong           Kershaw, Doug
# 8   Piano Sonata no. 3 in C major, op. 2 no. 3: I....   Beethoven, Ludwig van
# 9                                         Coming Home                    None
# 10                                Point of Extinction  Motion City Soundtrack
#
# [10 rows x 42 columns]

# %%
#loads features extracted from acousticbrainz lowlevel features, from 3 different csvs on their website
lowlevel = pd.read_csv("C:\\Users\\ryannewbury\\Downloads\\acousticbrainz-lowlevel-features-20220623\\acousticbrainz-lowlevel-features-20220623-lowlevel.csv")
rhythm = pd.read_csv("C:\\Users\\ryannewbury\\Downloads\\acousticbrainz-lowlevel-features-20220623\\acousticbrainz-lowlevel-features-20220623-rhythm.csv")
tonal = pd.read_csv("C:\\Users\\ryannewbury\\Downloads\\acousticbrainz-lowlevel-features-20220623\\acousticbrainz-lowlevel-features-20220623-tonal.csv")

# %%
lowlevel.head(10)
# Out:
#                                    mbid  submission_offset  average_loudness  \
# 0  0e11c0fd-a1da-4b88-a438-7ef55c5809ec                  0          0.703280
# 1  7fef22bd-76aa-4803-b56b-93a5d6e70662                  0          0.657434
# 2  71c0e054-b700-4fd2-a35b-95c7afc566cb                  0          0.228847
# 3  2d1201cf-59bb-4ffa-9f52-f5b3afa13346                  0          0.328406
# 4  96685213-a25c-4678-9a13-abd9ec81cf35                  0          0.570070
# 5  73b01cea-2dad-4fc2-9e61-02a31477c1b1                  0          0.168545
# 6  7c278a16-ae04-460c-88ea-39155cadcd09                  0          0.854816
# 7  19084069-642f-465f-9127-f71bcd800a05                  0          0.030876
# 8  70fda1f4-c0cf-4bb5-b25e-79b5e921b198                  0          0.925762
# 9  da39a905-7b84-4e2a-bbcf-74de3d6ebd03                  0          0.475052
#
#    dynamic_complexity  mfcc_zero_mean
# 0            5.612967     -722.370972
# 1            5.046805     -690.498535
# 2            5.314451     -706.800476
# 3            4.475980     -721.950439
# 4            9.305593     -784.208496
# 5            9.074841     -792.645020
# 6            2.146111     -652.554626
# 7            3.557840     -749.831482
# 8            2.719668     -646.503784
# 9            5.929364     -682.161255

# %%
rhythm.head(10)
# Out:
#                                    mbid  submission_offset         bpm  \
# 0  0e11c0fd-a1da-4b88-a438-7ef55c5809ec                  0  120.763885
# 1  7fef22bd-76aa-4803-b56b-93a5d6e70662                  0  125.956993
# 2  71c0e054-b700-4fd2-a35b-95c7afc566cb                  0  132.617203
# 3  2d1201cf-59bb-4ffa-9f52-f5b3afa13346                  0  144.318924
# 4  96685213-a25c-4678-9a13-abd9ec81cf35                  0  128.347702
# 5  73b01cea-2dad-4fc2-9e61-02a31477c1b1                  0  120.360603
# 6  7c278a16-ae04-460c-88ea-39155cadcd09                  0  151.575623
# 7  19084069-642f-465f-9127-f71bcd800a05                  0   82.642754
# 8  70fda1f4-c0cf-4bb5-b25e-79b5e921b198                  0  129.358032
# 9  da39a905-7b84-4e2a-bbcf-74de3d6ebd03                  0   91.101822
#
#    bpm_histogram_first_peak_bpm_mean  bpm_histogram_first_peak_bpm_median  \
# 0                              120.0                                120.0
# 1                              126.0                                126.0
# 2                              133.0                                133.0
# 3                              144.0                                144.0
# 4                              129.0                                129.0
# 5                              120.0                                120.0
# 6                              152.0                                152.0
# 7                               82.0                                 82.0
# 8                              129.0                                129.0
# 9                               91.0                                 91.0
#
#    bpm_histogram_second_peak_bpm_mean  bpm_histogram_second_peak_bpm_median  \
# 0                               133.0                                 133.0
# 1                               136.0                                 136.0
# 2                               140.0                                 140.0
# 3                               152.0                                 152.0
# 4                               120.0                                 120.0
# 5                               115.0                                 115.0
# 6                               157.0                                 157.0
# 7                                94.0                                  94.0
# 8                               123.0                                 123.0
# 9                               172.0                                 172.0
#
#    danceability  onset_rate
# 0      0.996203    2.867577
# 1      1.131311    3.568778
# 2      0.915099    2.858371
# 3      0.972823    2.395773
# 4      1.102882    2.419718
# 5      0.974217    1.876432
# 6      1.139013    3.394924
# 7      0.872103    5.799162
# 8      1.155036    3.361048
# 9      1.073015    2.519788

# %%
tonal.head(10)
# Out:
#                                    mbid  submission_offset key_key key_scale  \
# 0  0e11c0fd-a1da-4b88-a438-7ef55c5809ec                  0       A     major
# 1  7fef22bd-76aa-4803-b56b-93a5d6e70662                  0       A     major
# 2  71c0e054-b700-4fd2-a35b-95c7afc566cb                  0       G     major
# 3  2d1201cf-59bb-4ffa-9f52-f5b3afa13346                  0       D     major
# 4  96685213-a25c-4678-9a13-abd9ec81cf35                  0       A     minor
# 5  73b01cea-2dad-4fc2-9e61-02a31477c1b1                  0       G     minor
# 6  7c278a16-ae04-460c-88ea-39155cadcd09                  0       G     major
# 7  19084069-642f-465f-9127-f71bcd800a05                  0       D     minor
# 8  70fda1f4-c0cf-4bb5-b25e-79b5e921b198                  0       E     major
# 9  da39a905-7b84-4e2a-bbcf-74de3d6ebd03                  0       A     major
#
#    tuning_frequency  tuning_equal_tempered_deviation
# 0        434.193115                         0.141634
# 1        434.193115                         0.177662
# 2        434.193115                         0.234276
# 3        434.193115                         0.219335
# 4        434.193115                         0.164615
# 5        442.548920                         0.000000
# 6        434.193115                         0.224572
# 7        434.193115                         0.195417
# 8        445.112549                         0.095341
# 9        444.598633                         0.032828

# %%
#length of the 3 csv files
len(rhythm)
# Out:
# 29460584

# %%
len(tonal)
# Out:
# 29460584

# %%
len(lowlevel)
# Out:
# 29460584

# %%
#number of unique ids in csvs
rhythm['mbid'].nunique()
# Out:
# 7564215

# %%
tonal['mbid'].nunique()
# Out:
# 7564215

# %%
lowlevel['mbid'].nunique()
# Out:
# 7564215

# %%
#dropping duplicates from csvs
rhythm = rhythm.drop_duplicates(subset = ['mbid'], ignore_index = True)

# %%
len(rhythm)
# Out:
# 7564215

# %%
tonal = tonal.drop_duplicates(subset = ['mbid'], ignore_index = True)

# %%
len(tonal)
# Out:
# 7564215

# %%
lowlevel = lowlevel.drop_duplicates(subset = ['mbid'], ignore_index = True)

# %%
len(lowlevel)
# Out:
# 7564215

# %%
#joining all data into one dataframe
data1 = data.set_index('id').join(rhythm.set_index('mbid'),how = 'left',rsuffix = '_2')

# %%
data2 = data1.join(tonal.set_index('mbid'),how = 'left', rsuffix = '_2')

# %%
data3 = data2.join(lowlevel.set_index('mbid'),how = 'left', rsuffix = '_2')

# %%
len(data3)
# Out:
# 730178

# %%
data3.head(10)
# Out:
#                                      id  danceability  gender_male  \
# 0  00000baf-9215-483a-8900-93756eaf1cfc  9.999094e-01     0.500000
# 1  00002fc9-7283-44dd-bf6f-94c9492d0998  9.128905e-01     0.177181
# 2  00005a44-2152-4971-80c1-c217563845eb  2.611271e-01     0.013684
# 3  000078f4-308b-44a1-8601-6bc37d9e1623  4.287960e-07     0.490970
# 4  00007960-9d81-4192-b548-ad33d6b0ca54  4.546444e-01     0.922832
# 5  00008af6-1070-45d5-936d-fd22a5394dd7  9.482443e-01     0.149076
# 6  0000975b-110a-428a-b329-5207d4eb675f  1.068272e-01     0.985882
# 7  0000bbe1-12f7-48de-8737-a5ac362e76c8  7.733440e-03     0.875382
# 8  0000d8a7-8a9b-4b9d-a95c-038c6cb66547  9.612730e-01     0.939157
# 9  0001093f-3ca1-42c8-bcc7-8fbbcd2f7c72  2.814359e-01     0.983833
#
#     alternative         blues  electronic   folkcountry   funksoulrnb  \
# 0  1.232231e-01  2.935208e-02    0.678169  1.836665e-02  4.645366e-03
# 1  6.570297e-02  6.069383e-02    0.538495  1.011928e-01  2.309020e-02
# 2  8.683714e-03  4.818535e-04    0.988906  9.305365e-04  3.203383e-05
# 3  1.094945e-01  2.266773e-03    0.862300  1.392666e-02  2.019748e-04
# 4  4.180764e-01  4.206907e-02    0.384046  5.705131e-02  4.202647e-03
# 5  1.588343e-01  8.892059e-02    0.345241  8.827031e-02  2.571717e-02
# 6  7.420029e-02  1.136003e-01    0.371166  2.652968e-01  1.488504e-02
# 7  4.348425e-14  5.558130e-14    1.000000  2.061889e-08  1.918473e-08
# 8  2.280277e-01  2.217325e-02    0.621480  6.854345e-02  2.393640e-03
# 9  1.495392e-01  3.137565e-02    0.669721  4.712693e-02  3.812399e-03
#
#            jazz           pop  ...  onset_rate  submission_offset_2 key_key  \
# 0  2.795881e-02  7.834436e-03  ...    3.725091                    0       A
# 1  3.234591e-02  3.749089e-02  ...    3.908956                    0      A#
# 2  2.341192e-04  7.360673e-05  ...    2.669715                    0       D
# 3  4.161819e-04  2.697128e-03  ...    3.020281                    0       G
# 4  6.691809e-03  1.481296e-02  ...    2.074923                    0       A
# 5  6.783130e-02  4.839006e-02  ...    3.493876                    0       F
# 6  2.762670e-02  1.748554e-02  ...    3.073224                    0      D#
# 7  1.619071e-07  1.467535e-08  ...    3.330849                    0       C
# 8  4.151657e-03  9.586353e-03  ...    2.896211                    0       G
# 9  6.459226e-03  7.076079e-03  ...    3.423560                    0      D#
#
#    key_scale  tuning_frequency  tuning_equal_tempered_deviation  \
# 0      minor        434.193115                         0.238814
# 1      major        434.193115                         0.189041
# 2      minor        442.037933                         0.025623
# 3      major        438.984558                         0.056967
# 4      minor        434.193115                         0.253977
# 5      minor        453.940613                         0.347294
# 6      major        456.043091                         0.176944
# 7      major        448.467560                         0.000000
# 8      major        441.017792                         0.014545
# 9      major        440.508636                         0.019257
#
#    submission_offset_2.1  average_loudness  dynamic_complexity  mfcc_zero_mean
# 0                      0          0.955147            2.210088     -612.303894
# 1                      0          0.935944            3.924670     -687.685669
# 2                      0          0.902541            3.104318     -653.310913
# 3                      0          0.962707            2.667426     -589.021790
# 4                      0          0.962148            2.348460     -642.020752
# 5                      0          0.959342            3.295431     -645.288147
# 6                      0          0.731738            4.467504     -714.238098
# 7                      0          0.160667            7.483846     -848.829590
# 8                      0          0.946732            2.265507     -612.595093
# 9                      0          0.948849            2.752212     -612.611450
#
# [10 rows x 59 columns]

# %%
data3.isnull().sum()
# Out:
# id                                           0
# danceability                                 0
# gender_male                                  0
# alternative                                  0
# blues                                        0
# electronic                                   0
# folkcountry                                  0
# funksoulrnb                                  0
# jazz                                         0
# pop                                          0
# raphiphop                                    0
# rock                                         0
# genre                                        0
# acoustic                                     0
# aggressive                                   0
# mood_electronic                              0
# happy                                        0
# party                                        0
# relaxed                                      0
# sad                                          0
# mood_mirex_1                                 0
# mood_mirex_2                                 0
# mood_mirex_3                                 0
# mood_mirex_4                                 0
# mood_mirex_5                                 0
# timbre_bright                                0
# tonal                                        0
# instrumental                                 0
# bit_rate                                     0
# codec                                        0
# length                                       0
# lossless                                     0
# replay_gain                                  0
# true_genre                              156486
# artist                                    4525
# album                                       20
# bpm                                     491611
# year                                         0
# date                                       785
# label                                   197999
# song                                         4
# artistsort                              184181
# submission_offset                            0
# bpm_2                                        0
# bpm_histogram_first_peak_bpm_mean            0
# bpm_histogram_first_peak_bpm_median          0
# bpm_histogram_second_peak_bpm_mean           0
# bpm_histogram_second_peak_bpm_median         0
# danceability_2                               0
# onset_rate                                   0
# submission_offset_2                          0
# key_key                                      0
# key_scale                                    0
# tuning_frequency                             0
# tuning_equal_tempered_deviation              0
# submission_offset_2.1                        0
# average_loudness                             0
# dynamic_complexity                           0
# mfcc_zero_mean                               0
# dtype: int64

# %%
data3.to_csv('data.csv')
